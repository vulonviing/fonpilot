# %%
import pandas as pd
from datetime import datetime

# %% [raw]
# data = pd.read_excel("enflasyonlar/united kingdom.xlsx")
# data

# %% [raw]
# data["Release Date"] = pd.to_datetime(data["Release Date"].str[:12], format='%b %d, %Y')
# data["Release Date"] = pd.to_datetime(data["Release Date"]) - pd.DateOffset(months=1)
# current_year = datetime.now().year
# data = data[(data['Release Date'].dt.year >= 2020) & (data['Release Date'].dt.year <= current_year)]

# %% [raw]
# data.to_csv("enflasyonlar/united kingdom.csv")
#
# data

# %% [raw]
# data = pd.read_excel("enflasyonlar/türkiye.xlsx")
# data

# %% [raw]
# data["Release Date"] = pd.to_datetime(data["Release Date"].str[:10], format='%d.%m.%Y')
# data["Release Date"] = pd.to_datetime(data["Release Date"]) - pd.DateOffset(months=1)
# current_year = datetime.now().year
# data = data[(data['Release Date'].dt.year >= 2020) & (data['Release Date'].dt.year <= current_year)]

# %% [raw]
# data.to_csv("enflasyonlar/türkiye.csv")
#
# data

# %% [markdown]
# # Türkiye

# %%
türkiye = pd.read_csv("enflasyonlar/türkiye.csv")
türkiye = türkiye.iloc[:, 1:]

# %%
türkiye['Actual'] = türkiye['Actual'].str.rstrip('%').astype('float') / 100.0
türkiye['Forecast'] = türkiye['Forecast'].str.rstrip('%').astype('float') / 100.0
türkiye['Previous'] = türkiye['Previous'].str.rstrip('%').astype('float') / 100.0
türkiye
# Out:
#    Release Date      Time  Actual  Forecast  Previous
# 0    2024-02-04  10:00:00     NaN       NaN    0.6486
# 1    2024-01-05  10:00:00  0.6486    0.6452    0.6477
# 2    2023-12-03  10:00:00  0.6477    0.6510    0.6198
# 3    2023-11-04  10:00:00  0.6198    0.6300    0.6136
# 4    2023-10-03  10:00:00  0.6136    0.6212    0.6153
# 5    2023-09-03  10:00:00  0.6153    0.6170    0.5894
# 6    2023-08-04  10:00:00  0.5894    0.5590    0.4783
# 7    2023-07-03  10:00:00  0.4783    0.4730    0.3821
# 8    2023-06-05  10:00:00  0.3821    0.3947    0.3959
# 9    2023-05-05  10:00:00  0.3959    0.3920    0.4368
# 10   2023-04-03  10:00:00  0.4368    0.5133    0.5051
# 11   2023-03-03  10:00:00  0.5051    0.5133    0.5518
# 12   2023-02-03  10:00:00  0.5518    0.5550    0.5768
# 13   2023-01-03  10:00:00  0.5768    0.5350    0.6427
# 14   2022-12-03  10:00:00  0.6427    0.6653    0.8439
# 15   2022-11-05  10:00:00  0.8439    0.8465    0.8551
# ...
