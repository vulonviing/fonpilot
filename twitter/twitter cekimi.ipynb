# %%
import pyautogui
import numpy as np
import cv2
import pydirectinput
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import os
import shutil
from datetime import datetime

# %%
x, y = pyautogui.position()
print(f'Fare imlecinin konumu: x={x}, y={y}')
# Out:
# Fare imlecinin konumu: x=1284, y=101

# %%
# Tarayıcıyı başlat
driver = webdriver.Chrome()

# Tableau linkini aç
url = "https://public.tableau.com/app/profile/emrecan.ulu/viz/FonPilotDev/AnaSayfa"
driver.get(url)

# Pencereyi maksimize et
driver.maximize_window()

# Sayfayı yenile
driver.refresh()

# Ekranı en öne getir
driver.switch_to.window(driver.current_window_handle)

time.sleep(10)

screenshot = pyautogui.screenshot()
screenshot = np.array(screenshot)
screenshot = screenshot[:, :, ::-1]
yukari_template = cv2.imread('BUTON.png')
result = cv2.matchTemplate(screenshot, yukari_template, cv2.TM_CCOEFF_NORMED)
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
top_left = max_loc
bottom_right = (top_left[0] + yukari_template.shape[1], top_left[1] + yukari_template.shape[0])
if max_val > 0.8:
    print("Buton bulundu. Ekran Öne Alındı")
    button_location = (top_left[0] + yukari_template.shape[1] // 2, top_left[1] + yukari_template.shape[0] // 2)
    pydirectinput.click(button_location[0], button_location[1])
else:
    print("Buton bulunamadı.")


time.sleep(10)
pydirectinput.press('F11')
time.sleep(2)

# Görüntü konumunu belirleme
image_x = 1831
image_y = 23

# Ekran görüntüsü al
screenshot = pyautogui.screenshot()
screenshot = np.array(screenshot)
screenshot = screenshot[:, :, ::-1]

# Görüntü eşleştirme - 1
yukari_template = cv2.imread('BUTON1.png')
result = cv2.matchTemplate(screenshot, yukari_template, cv2.TM_CCOEFF_NORMED)
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
top_left = max_loc
bottom_right = (top_left[0] + yukari_template.shape[1], top_left[1] + yukari_template.shape[0])

# Buton bulunduysa
if max_val > 0.8:
    print("Buton bulundu.")
    button_location = (top_left[0] + yukari_template.shape[1] // 2, top_left[1] + yukari_template.shape[0] // 2)
    pydirectinput.click(button_location[0], button_location[1])
else:
    print("Buton bulunamadı.")

time.sleep(12)

# Ekran görüntüsü al
screenshot = pyautogui.screenshot()
screenshot = np.array(screenshot)
screenshot = screenshot[:, :, ::-1]

# Görüntü eşleştirme - 2
yukari_template = cv2.imread('BUTON2.png')
result = cv2.matchTemplate(screenshot, yukari_template, cv2.TM_CCOEFF_NORMED)
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
top_left = max_loc
bottom_right = (top_left[0] + yukari_template.shape[1], top_left[1] + yukari_template.shape[0])

# Buton bulunduysa
if max_val > 0.8:
    print("Buton bulundu.")
    button_location = (top_left[0] + yukari_template.shape[1] // 2, top_left[1] + yukari_template.shape[0] // 2)
    pydirectinput.click(button_location[0], button_location[1])
else:
    print("Buton bulunamadı.")

time.sleep(3)

# Ekran görüntüsü al
screenshot = pyautogui.screenshot()
screenshot = np.array(screenshot)
screenshot = screenshot[:, :, ::-1]

# Fare hareketi
#pydirectinput.move(0, -80)
#pydirectinput.click()
#Fare Hareketi Yapıldı

# Görüntü eşleştirme - 3
yukari_template = cv2.imread('BUTON3.png')
result = cv2.matchTemplate(screenshot, yukari_template, cv2.TM_CCOEFF_NORMED)
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
top_left = max_loc
bottom_right = (top_left[0] + yukari_template.shape[1], top_left[1] + yukari_template.shape[0])

# Buton bulunduysa
if max_val > 0.8:
    print("Buton bulundu.")
    button_location = (top_left[0] + yukari_template.shape[1] // 2, top_left[1] + yukari_template.shape[0] // 2)
    pydirectinput.click(button_location[0], button_location[1])
else:
    print("Buton bulunamadı.")

time.sleep(12)

driver.quit()

default_download_path = r"C:\Users\emrec\Downloads"
downloaded_files = os.listdir(default_download_path)
downloaded_files_sorted = sorted(downloaded_files, key=lambda x: os.path.getctime(os.path.join(default_download_path, x)), reverse=True)
target_directory = r"C:\Users\emrec\Desktop\ibb lab first case\tefasfoncekimi\twitter\Fonlar Tablosu"
new_file_name = f"Fonlar Tablosu {datetime.now().strftime('%Y-%m-%d')}"
os.rename(os.path.join(default_download_path, downloaded_files_sorted[0]), os.path.join(default_download_path, f"{new_file_name}.png"))
shutil.move(os.path.join(default_download_path, f"{new_file_name}.png"), target_directory)
# Out:
# Buton bulundu. Ekran Öne Alındı
# Buton bulundu.
# Buton bulundu.
# Buton bulundu.
# 'C:\\Users\\emrec\\Desktop\\ibb lab first case\\tefasfoncekimi\\twitter\\Fonlar Tablosu\\Fonlar Tablosu 2024-02-20.png'

# %%
# Tarayıcıyı başlat
driver = webdriver.Chrome()

# Tableau linkini aç
url = "https://public.tableau.com/app/profile/emrecan.ulu/viz/FonPilotDev/AnaSayfa"
driver.get(url)

# Pencereyi maksimize et
driver.maximize_window()

# Sayfayı yenile
driver.refresh()

# Ekranı en öne getir
driver.switch_to.window(driver.current_window_handle)

time.sleep(10)

screenshot = pyautogui.screenshot()
screenshot = np.array(screenshot)
screenshot = screenshot[:, :, ::-1]
yukari_template = cv2.imread('BUTON.png')
result = cv2.matchTemplate(screenshot, yukari_template, cv2.TM_CCOEFF_NORMED)
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
top_left = max_loc
bottom_right = (top_left[0] + yukari_template.shape[1], top_left[1] + yukari_template.shape[0])
if max_val > 0.8:
    print("Buton bulundu. Ekran Öne Alındı")
    button_location = (top_left[0] + yukari_template.shape[1] // 2, top_left[1] + yukari_template.shape[0] // 2)
    pydirectinput.click(button_location[0], button_location[1])
else:
    print("Buton bulunamadı.")


time.sleep(10)
pydirectinput.press('F11')
time.sleep(2)

# Görüntü konumunu belirleme
image_x = 1831
image_y = 23

# Ekran görüntüsü al
screenshot = pyautogui.screenshot()
screenshot = np.array(screenshot)
screenshot = screenshot[:, :, ::-1]

# Görüntü eşleştirme - 1
yukari_template = cv2.imread('BUTON4.png')
result = cv2.matchTemplate(screenshot, yukari_template, cv2.TM_CCOEFF_NORMED)
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
top_left = max_loc
bottom_right = (top_left[0] + yukari_template.shape[1], top_left[1] + yukari_template.shape[0])

# Buton bulunduysa
if max_val > 0.8:
    print("Buton bulundu.")
    button_location = (top_left[0] + yukari_template.shape[1] // 2, top_left[1] + yukari_template.shape[0] // 2)
    pydirectinput.click(button_location[0], button_location[1])
else:
    print("Buton bulunamadı.")

time.sleep(12)

# Ekran görüntüsü al
screenshot = pyautogui.screenshot()
screenshot = np.array(screenshot)
screenshot = screenshot[:, :, ::-1]

# Görüntü eşleştirme - 2
yukari_template = cv2.imread('BUTON2.png')
result = cv2.matchTemplate(screenshot, yukari_template, cv2.TM_CCOEFF_NORMED)
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
top_left = max_loc
bottom_right = (top_left[0] + yukari_template.shape[1], top_left[1] + yukari_template.shape[0])

# Buton bulunduysa
if max_val > 0.8:
    print("Buton bulundu.")
    button_location = (top_left[0] + yukari_template.shape[1] // 2, top_left[1] + yukari_template.shape[0] // 2)
    pydirectinput.click(button_location[0], button_location[1])
else:
    print("Buton bulunamadı.")

time.sleep(3)

# Ekran görüntüsü al
screenshot = pyautogui.screenshot()
screenshot = np.array(screenshot)
screenshot = screenshot[:, :, ::-1]

# Fare hareketi
#pydirectinput.move(0, -80)
#pydirectinput.click()
#Fare Hareketi Yapıldı

# Görüntü eşleştirme - 3
yukari_template = cv2.imread('BUTON3.png')
result = cv2.matchTemplate(screenshot, yukari_template, cv2.TM_CCOEFF_NORMED)
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
top_left = max_loc
bottom_right = (top_left[0] + yukari_template.shape[1], top_left[1] + yukari_template.shape[0])

# Buton bulunduysa
if max_val > 0.8:
    print("Buton bulundu.")
    button_location = (top_left[0] + yukari_template.shape[1] // 2, top_left[1] + yukari_template.shape[0] // 2)
    pydirectinput.click(button_location[0], button_location[1])
else:
    print("Buton bulunamadı.")

time.sleep(12)

driver.quit()

default_download_path = r"C:\Users\emrec\Downloads"
downloaded_files = os.listdir(default_download_path)
downloaded_files_sorted = sorted(downloaded_files, key=lambda x: os.path.getctime(os.path.join(default_download_path, x)), reverse=True)
target_directory = r"C:\Users\emrec\Desktop\ibb lab first case\tefasfoncekimi\twitter\Para Hareketi Tablosu"
new_file_name = f"Para Hareketi Tablosu {datetime.now().strftime('%Y-%m-%d')}"
os.rename(os.path.join(default_download_path, downloaded_files_sorted[0]), os.path.join(default_download_path, f"{new_file_name}.png"))
shutil.move(os.path.join(default_download_path, f"{new_file_name}.png"), target_directory)
# Out:
# Buton bulunamadı.
# Buton bulundu.
# Buton bulundu.
# Buton bulundu.
# 'C:\\Users\\emrec\\Desktop\\ibb lab first case\\tefasfoncekimi\\twitter\\Para Hareketi Tablosu\\Para Hareketi Tablosu 2024-02-20.png'
